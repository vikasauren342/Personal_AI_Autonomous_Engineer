# %% [markdown]
# # Personal AI — One Click Bootstrap
# This notebook is intentionally short. It detects Colab/Kaggle/local runtime, installs only runtime dependencies if needed, boots the canonical core, and runs health + smoke tests.

# %%
# !pip -q install -r /content/Personal_AI_AGI_Ready_Core_v3_0/requirements-runtime.txt || true

# %%
import os,sys,pathlib
ROOT=pathlib.Path(os.environ.get('PERSONAL_AI_ROOT','/content/Personal_AI_AGI_Ready_Core_v3_0'))
sys.path.insert(0,str(ROOT))
from personal_ai.app import PersonalAI
ai=PersonalAI.bootstrap(ROOT)
print(ai.health())

# %%
print(ai.ask('Run a smoke test of memory, routing, model fallback, evaluation and learning ledger.'))
print('READY: canonical Personal AI core is connected.')
